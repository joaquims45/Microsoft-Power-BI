# %%
import pandas as pd
import numpy as np

# %%
ruta_archivo = r'C:\Users\Usuario\Documents\PowerBI\Untitled Folder\Ventas_Videojuegos.xlsx'
df = pd.read_excel(ruta_archivo)

# %%
df
# Out:
#                                                   Nombre Plataforma   Año  \
# 0                                             Wii Sports        Wii  2006
# 1                                      Super Mario Bros.        NES  1985
# 2                                         Mario Kart Wii        Wii  2008
# 3                                      Wii Sports Resort        Wii  2009
# 4                               Pokemon Red/Pokemon Blue         GB  1996
# ...                                                  ...        ...   ...
# 16321                      Farming 2017 - The Simulation        PS4  2016
# 16322                                  Rugby Challenge 3       XOne  2016
# 16323  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...        PSV  2016
# 16324   Phantasy Star Online 2 Episode 4: Deluxe Package        PSV  2017
# 16325                   Brothers Conflict: Precious Baby        PSV  2017
#
#              Genero             Editorial  Ventas NA  Ventas EU  Ventas JP  \
# ...

# %%
missing_values_count = df.isnull().sum()

# %%
missing_values_count[0:10]
# Out:
# Nombre            0
# Plataforma        0
# Año               0
# Genero            0
# Editorial        36
# Ventas NA         0
# Ventas EU         0
# Ventas JP         0
# Ventas Otros      0
# Ventas Global     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
missing_values_count = df.isnull().sum()

# %%
missing_values_count[0:10]
# Out:
# Nombre           0
# Plataforma       0
# Año              0
# Genero           0
# Editorial        0
# Ventas NA        0
# Ventas EU        0
# Ventas JP        0
# Ventas Otros     0
# Ventas Global    0
# dtype: int64

# %%
df
# Out:
#                                                   Nombre Plataforma   Año  \
# 0                                             Wii Sports        Wii  2006
# 1                                      Super Mario Bros.        NES  1985
# 2                                         Mario Kart Wii        Wii  2008
# 3                                      Wii Sports Resort        Wii  2009
# 4                               Pokemon Red/Pokemon Blue         GB  1996
# ...                                                  ...        ...   ...
# 16321                      Farming 2017 - The Simulation        PS4  2016
# 16322                                  Rugby Challenge 3       XOne  2016
# 16323  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...        PSV  2016
# 16324   Phantasy Star Online 2 Episode 4: Deluxe Package        PSV  2017
# 16325                   Brothers Conflict: Precious Baby        PSV  2017
#
#              Genero             Editorial  Ventas NA  Ventas EU  Ventas JP  \
# ...

# %%
df.rename(columns={'Ventas NA': 'Norteamerica', 'Ventas EU': 'Europa','Ventas JP': 'Japón', 'Ventas Otros': 'Otros', 'Ventas Global': 'Global'}, inplace=True)

# %%
df
# Out:
#                                                   Nombre Plataforma   Año  \
# 0                                             Wii Sports        Wii  2006
# 1                                      Super Mario Bros.        NES  1985
# 2                                         Mario Kart Wii        Wii  2008
# 3                                      Wii Sports Resort        Wii  2009
# 4                               Pokemon Red/Pokemon Blue         GB  1996
# ...                                                  ...        ...   ...
# 16321                      Farming 2017 - The Simulation        PS4  2016
# 16322                                  Rugby Challenge 3       XOne  2016
# 16323  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...        PSV  2016
# 16324   Phantasy Star Online 2 Episode 4: Deluxe Package        PSV  2017
# 16325                   Brothers Conflict: Precious Baby        PSV  2017
#
#              Genero             Editorial  Norteamerica  Europa  Japón  Otros  \
# ...

# %%
df.to_excel(ruta_archivo, index=False)
